# %% [markdown]
# Notebook to explore SEER data

# %%
import pandas as pd

# %%
# !pwd
# Out:
# /Users/patxiestomba/canceritos/notebooks

# %%
file_name = "../data/processed/seer/incidence/yr1973_2008.seer9/COLRECT_FILTERED.csv"

# %%
data = pd.read_csv(file_name, sep=",", usecols=columns_keep, dtype=str)

# %%
# %matplotlib inline

# %% [markdown]
# ## Exploratory

# %%
from matplotlib import pyplot as plt

fig, axs = plt.subplots(nrows=len(cols_to_plot), figsize=(15, 100))
for i, col in enumerate(cols_to_plot):
    sns.countplot(x=col, data=data, ax=axs[i])

# %% [markdown]
# ## Correlation with survival

# %%
import seaborn as sns

# %%
g = sns.FacetGrid(data, col="class", sharex=False)
g.map(sns.boxplot, "deck", "age");

# %%
#boxplot survival-
g=sns.PairGrid(data,
               x_vars=["Grade","Race recode (W, B, AI, API)"],
               y_vars=["Survival months"],
              aspect=.75,size=6.5)
g.map(sns.violinplot,palette="pastel");
